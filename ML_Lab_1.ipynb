# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshath13/Machine-Learning-Labs/blob/main/ML_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/travel insurance.csv")

#f=df['Agency Type'].unique()
#f

# %%
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70    NaN   32
# 3    No        60   AUSTRALIA      -39.6                 23.76    NaN   32
# 4    No        79       ITALY      -19.8                 11.88    NaN   41

# %% [markdown]
# Method to change Categorical variable to Numeric Values

# %%
df.dropna(subset=['Gender'],axis=0,inplace=True)
df
# Out:
#       Agency    Agency Type Distribution Channel        Product Name Claim  \
# 0        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 1        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 5        JZI       Airlines               Online          Value Plan    No
# 11       JZI       Airlines               Online          Basic Plan    No
# 12       KML  Travel Agency               Online        Premier Plan    No
# ...      ...            ...                  ...                 ...   ...
# 63321    JZI       Airlines               Online          Basic Plan    No
# 63322    JZI       Airlines               Online          Basic Plan    No
# 63323    JZI       Airlines               Online          Basic Plan    No
# 63324    JZI       Airlines               Online          Basic Plan    No
# 63325    JZI       Airlines               Online          Basic Plan    No
#
# ...

# %%
mean=df['Commision (in value)'].mean()
mean.round(2)
# Out:
# 18.48

# %%
new=df['Commision (in value)'].replace(np.nan,mean,inplace=True)
#filt=df['Commision (in value)']==18.48

# %%
for coln in df:
  df[coln] = df[coln].astype('category').cat.codes
df#print(np.sort(df[cols].unique()))
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Claim  \
# 0           3            1                     0             9      0
# 1           3            1                     0             9      0
# 5           8            0                     1            21      0
# 11          8            0                     1             6      0
# 12          9            1                     1            12      0
# ...       ...          ...                   ...           ...    ...
# 63321       8            0                     1             6      0
# 63322       8            0                     1             6      0
# 63323       8            0                     1             6      0
# 63324       8            0                     1             6      0
# 63325       8            0                     1             6      0
#
#        Duration  Destination  Net Sales  Commision (in value)  Gender  Age
# ...

# %% [markdown]
# Another Method to convert categ to num variable

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Destination']=lb.fit_transform(df['Destination'])
df.head()
# Out:
#     Agency  Agency Type  Distribution Channel  Product Name  Claim  Duration  \
# 0        3            1                     0             9      0       187
# 1        3            1                     0             9      0       187
# 5        8            0                     1            21      0        67
# 11       8            0                     1             6      0         2
# 12       9            1                     1            12      0        54
#
#     Destination  Net Sales  Commision (in value)  Gender  Age
# 0            43         47                   219       0   80
# 1            43         47                   219       0   70
# 5            79         14                   617       0   43
# 11           43         58                   136       1   46
# 12           56         12                   642       0   47

# %%
y=df['Claim']
y.unique()
# Out:
# array([0, 1], dtype=int8)

# %%
l = df.columns.tolist()
l.remove("Claim")
l.
# Out:
#   File "<ipython-input-16-73a7aae8bc7c>", line 3
#     l.
#       ^
# SyntaxError: invalid syntax

# %%
x=df.drop('Claim',axis=1)
x
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Duration  \
# 0           3            1                     0             9       187
# 1           3            1                     0             9       187
# 5           8            0                     1            21        67
# 11          8            0                     1             6         2
# 12          9            1                     1            12        54
# ...       ...          ...                   ...           ...       ...
# 63321       8            0                     1             6       112
# 63322       8            0                     1             6        59
# 63323       8            0                     1             6         3
# 63324       8            0                     1             6         4
# 63325       8            0                     1             6        23
#
#        Destination  Net Sales  Commision (in value)  Gender  Age
# ...

# %%
pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 69 kB 3.9 MB/s
# ...

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Agency',
 'Agency Type',
 'Distribution Channel',
 'Product Name',
 'Duration',
 'Destination',
 'Net Sales',
 'Commision (in value)',
 'Gender',
 'Age'])

x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
df.isnull().value_counts()

# %%
from sklearn.preprocessing import StandardScaler

x_train=StandardScaler().fit_transform(x_train)
x_test=StandardScaler().fit_transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[4223,  172],
#        [ 141,   19]])

# %%
from sklearn.tree import export_graphviz
import graphviz

graphviz.Source(export_graphviz(classifier,feature_names = x.columns,filled = True))
