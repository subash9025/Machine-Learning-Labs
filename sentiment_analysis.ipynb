# %% [markdown]
# <a href="https://colab.research.google.com/github/subash9025/Machine-Learning-Labs/blob/main/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\U0001f600")
print("\U0001f565")
print("\U0001F925")
# Out:
# 😀
# 🕥
# 🤥

# %%
print("\N{grinning face}")
print("\N{slightly smiling face}")
print("\N{winking face}")
# Out:
# 😀
# 🙂
# 😉

# %%
pip install emoji --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 216 kB 4.1 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=c9af354f8e50009dba8ace6d298de862dfa6275da83237eb1323facecd67f194
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# ...

# %%
import emoji
print(emoji.emojize('hi there! :revolving_heart:'))
# Out:
# hi there! :revolving_heart:

# %%
! pip install -q transformers
# Out:
#      |████████████████████████████████| 4.9 MB 3.2 MB/s
#      |████████████████████████████████| 120 kB 54.4 MB/s
#      |████████████████████████████████| 6.6 MB 34.1 MB/s

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")
data = ["your great","annoyed"]
sentiment_pipeline(data)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998618364334106},
#  {'label': 'NEGATIVE', 'score': 0.9997292160987854}]

# %%
specific_model=pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
specific_model(data)
# Out:
# Downloading:   0%|          | 0.00/890 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/843k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# [{'label': 'POS', 'score': 0.9873097538948059},
#  {'label': 'NEG', 'score': 0.9090029001235962}]

# %%
from textblob import TextBlob

testimonial = TextBlob("the food was great!")
print(testimonial.sentiment)
# Out:
# Sentiment(polarity=1.0, subjectivity=0.75)
